# %%
# R-15.1
'''
there are 133,000,000,000,000,000,000,000,000,000,000,000,000,000,000,000,000 atoms in the earth
the main memory of a computer cannot reach that size if different bits are presented by distinct atoms


'''

# %%
# R-15.2
'''
add an item to (a,b) tree:
insert the new key-value pair in an external node w, if there is an overflow occurs at w, split it into two equal-size node w1 and w2 by key k
if w is the root, create a new root u; else, let u be the parent of w, insert the key k into u, w1 and w2 are the new children of u
there might be another overflow occurs at the parent u, do the split operations recursively until reach the root

delete an item from (a,b) tree:
although the removed key may stored in an internal node, a key in the external node will fill its position, and will always leads to a reduction in an external node
if there is an underflow occurs at an external node w, firstly cheack if we can move a key from its siblings without violating the size property
if cannot, do the fusion operation: merge w with one of its siblings, get a new node w', move a key from its parent u to w'



'''

# %%
# R-15.3
'''
at leat 5 and at most 8 children, it chouldn't be
once there is an overflow node w with 9 children, it is splitted into node w1 with 5 children, and node w2 with 4 children, which violates "at least 5 children"


'''

# %%
# R-15.4
'''
b = d =8
'''

# %%
# R-15.5
''''
5 pages miss

|2 |3 |4 |1 | , 3 out
5  2  3  4 

|2 |5 |4 |1 | , 4 out
5  6  3  7 

|2 |5 |3 |1 | , 2 out
5  9  8  7 

|4 |5 |3 |1 | , 3 out
10  9  8  11 

|4 |5 |2 |1 | , 5 out
10  9  12  11 

|4 |3 |2 |1 | , 
10  13  12  11 
''''
# 1. in this case spatial locality cannot be considered

# %%
# R-15.6
'''
3 miss
|2 |3 |4 |1 | , 2 out

|5 |3 |4 |1 | , 3 out

|5 |2 |4 |1 | , 4 out

|5 |2 |3 |1 | ,
'''
# 1. the difference between LRU and FIFO is, in FIFO we don't update the priority even this page (block) in cache is visited again

# %%
# R-15.7
'''
4 pages capacity, 5 different pages in the request, always out the page visited in the next request
at most 8 miss

|2 |3 |4 |1 | , 1 out

|2 |3 |4 |5 | , 3 out

|2 |1 |4 |5 | , 5 out

|2 |1 |4 |3 | , 4 out

|2 |1 |5 |3 | , 1 out

|2 |4 |5 |3 | , 2 out

|1 |4 |5 |3 | , 3 out

|1 |4 |5 |2 | , any block may be out when visit 3

'''

# %%
# R-15.8
'''
b = d = 7 
a = ceiling(d/2) = 3


(4, 11, 23, 34, 40, 62, 78)     8 children > 7, overflow, split at key 34


          34
        /    \
  (4, 11, 23)    (40, 62, 78)


            34
          /    \
(4, 11, 22, 23, 25)   (40, 59, 62, 66, 72, 78, 90)   8 children > 7, overflow, split at key 66


               34, 66
           /     |     \
(4, 11, 22, 23, 25)  (40, 59, 62)  (72, 78, 90)
       

                    34, 66
             /        |        \
(4, 11, 12, 22, 23, 25) (39, 40, 59, 62, 64)  (72, 77, 78, 90)


'''
